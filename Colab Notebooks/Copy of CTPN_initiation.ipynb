# %%
# !git clone https://github.com/achbogga/text-detection-ctpn.git
# Out:
# Cloning into 'text-detection-ctpn'...
# remote: Enumerating objects: 3, done.
# remote: Counting objects: 100% (3/3), done.
# remote: Compressing objects: 100% (3/3), done.
# remote: Total 1070 (delta 0), reused 0 (delta 0), pack-reused 1067
# Receiving objects: 100% (1070/1070), 344.21 MiB | 34.54 MiB/s, done.
# Resolving deltas: 100% (445/445), done.

# %%
# !ls text-detection-ctpn
# Out:
# data  LICENSE  main  nets  README.md  requirements.txt	utils

# %%
# !cd text-detection-ctpn/utils/bbox && chmod +x make.sh && ./make.sh
# Out:
# running install
# running build
# running build_ext
# running install_lib
# running install_egg_info
# Removing /usr/local/lib/python3.6/dist-packages/UNKNOWN-0.0.0.egg-info
# Writing /usr/local/lib/python3.6/dist-packages/UNKNOWN-0.0.0.egg-info
# running install
# running build
# running build_ext
# running install_lib
# running install_egg_info
# Removing /usr/local/lib/python3.6/dist-packages/UNKNOWN-0.0.0.egg-info
# Writing /usr/local/lib/python3.6/dist-packages/UNKNOWN-0.0.0.egg-info

# %%
#You need to download the checkpoints from the repo to your corresponding google drive folder and extract the files.
#Then replace the following path accordingly.
from google.colab import drive
drive.mount('/content/gdrive')
# Out:
# Go to this URL in a browser: https://accounts.google.com/o/oauth2/auth?client_id=947318989803-6bn6qk8qdgf4n4g3pfee6491hc0brc4i.apps.googleusercontent.com&redirect_uri=urn%3aietf%3awg%3aoauth%3a2.0%3aoob&response_type=code&scope=email%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdocs.test%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdrive%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdrive.photos.readonly%20https%3a%2f%2fwww.googleapis.com%2fauth%2fpeopleapi.readonly
#
# Enter your authorization code:
# ··········
# Mounted at /content/gdrive
# ls: cannot access '/content/gdrive/My drive/ctpn_checkpoints/checkpoints_mlt/': No such file or directory

# %%
# !ls '/content/gdrive/My Drive'
# Out:
#  1306.0239.pdf
#  Achyut_Boggaram_2017_May.pdf
# 'Achyut Boggaram_latest_Nov_2019.pdf'
# 'ADC Ice Skating Registration.gform'
# 'BTech MarkSheet.jpg'
#  checkpoints_mlt.zip
# 'Colab Notebooks'
# 'crop_1 (1).jpg'
#  crop_1_enhanced.jpg
#  crop_1.gdoc
#  crop_1.jpg
#  ctpn_checkpoints
# 'Deep Learning R&D At Clobotics Corporation.pdf'
# 'degree certificate.pdf'
# 'face Databases.gsheet'
# 'Getting started.pdf'
# 'Google Keep Document.gdoc'
# 'i983 - achyut.pdf'
# 'Instructions for using the TitanXp Clobotics Machine.gdoc'
# 'Peer review.gdoc'
# 'Screenshot (Oct 3, 2019 4:36:49 PM)'
# 'Untitled document.gdoc'

# %%
# !mv '/content/gdrive/My Drive/ctpn_checkpoints/checkpoints_mlt' 'text-detection-ctpn/checkpoints_mlt'

# %%
ctpn_checkpoints_path = 'text-detection-ctpn/checkpoints_mlt'
import os
print (os.listdir(ctpn_checkpoints_path))
# Out:
# ['ctpn_50000.ckpt.data-00000-of-00001', 'ctpn_50000.ckpt.index', 'ctpn_50000.ckpt.meta', 'checkpoint']

# %%
# !ls text-detection-ctpn/data/demo
# Out:
# 006.jpg  007.jpg  008.jpg  009.jpg  010.png

# %%
# !cd text-detection-ctpn && python ./main/demo.py
# Out:
# WARNING:tensorflow:
# The TensorFlow contrib module will not be included in TensorFlow 2.0.
# For more information, please see:
#   * https://github.com/tensorflow/community/blob/master/rfcs/20180907-contrib-sunset.md
#   * https://github.com/tensorflow/addons
#   * https://github.com/tensorflow/io (for I/O related ops)
# If you depend on functionality not listed there, please file an issue.
#
# WARNING:tensorflow:From ./main/demo.py:121: The name tf.app.run is deprecated. Please use tf.compat.v1.app.run instead.
#
# WARNING:tensorflow:From ./main/demo.py:60: The name tf.get_default_graph is deprecated. Please use tf.compat.v1.get_default_graph instead.
#
# W1202 21:12:46.844151 140072561125248 module_wrapper.py:139] From ./main/demo.py:60: The name tf.get_default_graph is deprecated. Please use tf.compat.v1.get_default_graph instead.
#
# WARNING:tensorflow:From ./main/demo.py:61: The name tf.placeholder is deprecated. Please use tf.compat.v1.placeholder instead.
#
# ...
